# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

sns.countplot(x="Age", data=data_chilla)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

sns.countplot(x="Gender", hue= "Location", saturation=3, data=data_chilla)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

p1=sns.countplot(x="Gender", hue= "Location",  palette="bright",  data=data_chilla)
p1.set_title("Chilla Data plot")

# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla=pd.read_csv("Chilla_data2_for_plots.csv")
data_chilla.head()
#print (data)

# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")

p1=sns.countplot(x="Gender",  hue= "Qualification_completed",  palette="bright",  data=data_chilla1)
plt.xlabel("Gender",size=10, weight="bold")
plt.ylabel("Count", size=10, weight="bold")
p1.set_title("Data plot of all the participant in the Chilla", size=13, weight="bold")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")

h=sns.FacetGrid(data_chilla1,row="Age" ,hue="Are you Vaccinated?")
h=(h.map(plt.scatter, "Gender", "Location"  ).add_legend())
plt.show()

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            col="time", aspect=.8,
            kind="swarm", data=tips)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")


g =sns.scatterplot(x="Location", y="field_of_study", hue="Are you Vaccinated?", palette="bright",  data=data_chilla1)
# h =sns.scatterplot(x="Location", y="Gender",  data=data_chilla1)
plt.xlabel("Location",size=10, weight="bold")
plt.ylabel("field_of_study", size=10, weight="bold")
plt.title("Scatter plot of all the participant in the Chilla", size=13, weight="bold")
# Out:
# Text(0.5, 1.0, 'Scatter plot of all the participant in the Chilla')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example planets dataset
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")

# cmap = sns.cubehelix_palette(rot=-.2)
g = sns.relplot(
    data=data_chilla1,
    x="Location", y="field_of_study",
    hue="Gender", size="Are you Vaccinated?")
