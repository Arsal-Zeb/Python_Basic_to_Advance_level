# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

sns.countplot(x="Age", data=data_chilla)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

sns.countplot(x="Gender", hue= "Location", saturation=3, data=data_chilla)

# %%
import pandas as pd
import seaborn as sns


#import chilla data
data_chilla=pd.read_csv("data_viz.csv")
data_chilla.head()
#print (data)

p1=sns.countplot(x="Gender", hue= "Location",  palette="bright",  data=data_chilla)
p1.set_title("Chilla Data plot")

# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla=pd.read_csv("Chilla_data2_for_plots.csv")
data_chilla.head()
#print (data)
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
import pandas as pd
import seaborn as sns

#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")

p1=sns.countplot(x="Gender",  hue= "Qualification_completed",  palette="bright",  data=data_chilla1)
p1.set_title("Data plot of all the participant in the Chilla")
# Out:
# Text(0.5, 1.0, 'Data plot of all the participant in the Chilla')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")

h=sns.FacetGrid(data_chilla1,row="Age" ,hue="Are you Vaccinated?")
h=(h.map(plt.scatter, "Gender", "Location"  ).add_legend())
plt.show()

# %%
sns.catplot(x="day", y="total_bill", hue="sex",
            col="time", aspect=.8,
            kind="swarm", data=tips)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#import chilla data
data_chilla1=pd.read_csv("Chilla_data2_for_plots.csv")


g =sns.scatterplot(x="Location", y="field_of_study", hue="Are you Vaccinated?", data=data_chilla1)
# h =sns.scatterplot(x="Location", y="Gender",  data=data_chilla1)
